# %% [markdown]
# ## 학습모델 (NCF)

# %% [markdown]
# ### NCF (Neural Collaborative Filtering): GMF + MLP를 결합한 구조

# %% [markdown]
# #### GMF (Generalized Matrix Factorization): SVD와 비슷하지만 신경망으로 표현

# %%
"""
일반화 행렬 인수분해(Generalized Matrix Factorization, GMF):
전통적인 행렬 인수분해 방법을 사용합니다. 사용자-아이템 상호작용의 선형구조를 표현합니다.
"""

# %% [markdown]
# #### MLP (Multi-Layer Perceptron): 임베딩을 신경망에 넣어 학습

# %%
"""
다층 퍼셉트론 (Multi-Layer Perceptron, MLP):
여러개의 Layer로 더 복잡한 구조인 비선형성 구조를 학습할 수 있습니다.

모델이 이미지 분류 모델과 비슷한데,
이미지 분류에서 검증된 Dropout, BatchNorm, ReLU 같은 기법들은
벡터 데이터 회귀 모델에도 잘 작동하는 경우가 많음
"""

# %% [markdown]
# ##### SVD : Surprise의 행렬분해 기반 추천특화 머신러닝 모델
